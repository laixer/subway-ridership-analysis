# %%
import pandas
from ggplot import *
# %matplotlib inline

# %%
turnstile_data = pandas.read_csv('turnstile_weather_v2.csv')
turnstile_data['DATEn'] = pandas.to_datetime(turnstile_data['DATEn'])
turnstile_data.describe()
# Out:
#            ENTRIESn        EXITSn  ENTRIESn_hourly  EXITSn_hourly  \
# count  4.264900e+04  4.264900e+04     42649.000000   42649.000000
# mean   2.812486e+07  1.986993e+07      1886.589955    1361.487866
# std    3.043607e+07  2.028986e+07      2952.385585    2183.845409
# min    0.000000e+00  0.000000e+00         0.000000       0.000000
# 25%    1.039762e+07  7.613712e+06       274.000000     237.000000
# 50%    1.818389e+07  1.331609e+07       905.000000     664.000000
# 75%    3.263049e+07  2.393771e+07      2255.000000    1537.000000
# max    2.357746e+08  1.493782e+08     32814.000000   34828.000000
#
#                hour      day_week       weekday      latitude     longitude  \
# count  42649.000000  42649.000000  42649.000000  42649.000000  42649.000000
# mean      10.046754      2.905719      0.714436     40.724647    -73.940364
# std        6.938928      2.079231      0.451688      0.071650      0.059713
# ...

# %%
turnstile_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42649 entries, 0 to 42648
# Data columns (total 27 columns):
# UNIT               42649 non-null object
# DATEn              42649 non-null datetime64[ns]
# TIMEn              42649 non-null object
# ENTRIESn           42649 non-null int64
# EXITSn             42649 non-null int64
# ENTRIESn_hourly    42649 non-null float64
# EXITSn_hourly      42649 non-null float64
# datetime           42649 non-null object
# hour               42649 non-null int64
# day_week           42649 non-null int64
# weekday            42649 non-null int64
# station            42649 non-null object
# latitude           42649 non-null float64
# longitude          42649 non-null float64
# conds              42649 non-null object
# fog                42649 non-null int64
# precipi            42649 non-null float64
# pressurei          42649 non-null float64
# rain               42649 non-null int64
# tempi              42649 non-null float64
# ...

# %%
turnstile_data_by_date = turnstile_data[['DATEn', 'day_week', 'ENTRIESn_hourly']].groupby(['DATEn', 'day_week'], as_index=False).sum()
turnstile_data_by_date.describe()
# Out:
#         day_week  ENTRIESn_hourly
# count  31.000000        31.000000
# mean    2.935484   2595521.774194
# std     2.112431    710440.834289
# min     0.000000   1400098.000000
# 25%     1.000000   1891834.000000
# 50%     3.000000   3009536.000000
# 75%     5.000000   3137683.000000
# max     6.000000   3201840.000000

# %%
turnstile_data_by_date
# Out:
#         DATEn  day_week  ENTRIESn_hourly
# 0  2011-05-01         6          1563693
# 1  2011-05-02         0          2806944
# 2  2011-05-03         1          3183128
# 3  2011-05-04         2          3118915
# 4  2011-05-05         3          3199002
# 5  2011-05-06         4          3179032
# 6  2011-05-07         5          1877545
# 7  2011-05-08         6          1400098
# 8  2011-05-09         0          2834785
# 9  2011-05-10         1          3090088
# 10 2011-05-11         2          3169092
# 11 2011-05-12         3          3201840
# 12 2011-05-13         4          3114960
# 13 2011-05-14         5          1906123
# 14 2011-05-15         6          1413929
# 15 2011-05-16         0          2866698
# 16 2011-05-17         1          3032183
# 17 2011-05-18         2          3139070
# 18 2011-05-19         3          3136296
# 19 2011-05-20         4          3108151
# 20 2011-05-21         5          1966083
# 21 2011-05-22         6          1419988
# ...

# %%
turnstile_data_by_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 3 columns):
# DATEn              31 non-null datetime64[ns]
# day_week           31 non-null int64
# ENTRIESn_hourly    31 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 992.0 bytes

# %%
p = ggplot(turnstile_data_by_date, aes(x='DATEn', y='ENTRIESn_hourly')) + \
    geom_point() + \
    geom_line() + \
    scale_x_date(breaks=date_breaks('7 days'), labels = date_format("%Y-%m-%d"))
p.draw()

# %% [markdown]
# Interesting to note that ridership on Mondays appears to be lower than on other weekdays.
#
# In this sample, ridership is lowest on Sundays, followed by Saturdays,

# %%
turnstile_data_weather = turnstile_data[['DATEn', 'rain']].groupby(['DATEn'], as_index=False).aggregate(lambda x: sum(x) / float(len(x)))
#turnstile_data_weather

# %%
ggplot(turnstile_data_weather, aes(x='DATEn', y='rain')) + \
    geom_point() + \
    geom_line()
# Out:
# <ggplot: (8782256794189)>
